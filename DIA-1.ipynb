# %%
print('hola mundo')
# Out:
# hola mundo

# %%
nombre = 'martin' 
edad = 22 #-> int 
ciudad = 'ita' 
print(nombre)
print(edad)
print(ciudad)
# Out:
# martin
# 22
# ita

# %%
cantidad_de_manzanas = 28
cantidad_de_naranjas = 35
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print('la cantidad_de_frutas es ', cantidad_de_frutas)
# Out:
# la cantidad_de_frutas es  63

# %%
frutas_vendidas = 89
cantidad_de_frutas = 67
frutas_restantes = frutas_vendidas - cantidad_de_frutas
print('la cantidad de frutas vendidas es', frutas_restantes)
# Out:
# la cantidad de frutas vendidas es 22

# %%
nombre = 'adam'
apellido = 'balbuena' 
print(f'mi amigo se llama {nombre} {apellido} ')
# Out:
# mi amigo se llama adam balbuena

# %%
cantidad_de_caramelos = int(input('digame su cantidad de caramelos'))
cantidad_de_chicos = int(input('digame la cantidad de chicos'))
caramelos_por_chicos = cantidad_de_caramelos // cantidad_de_chicos
print(f'la cantidad que recibe cada chico seria: {cantidad_de_chicos}')
sobrantes_caramelos = cantidad_de_caramelos % cantidad_de_chicos
print(f'la cantidad sobrante de caramelos seria: {sobrantes_caramelos}')
# Out:
# la cantidad que recibe cada chico seria: 8
# la cantidad sobrante de caramelos seria: 7

# %%
ciudad = input('diga su ciudad')
barrio = input('especifique su barrio')
print(f'yo soy de {ciudad} y mi barrio es {barrio}')

def su_ubicacion():
    ciudad = input('diga su ciudad')
    barrio = input('especifique su barrio')
    print(f'yo soy de {ciudad} y mi barrio es {barrio}')

su_ubicacion()
su_ubicacion()
# Out:
# yo soy de ITA y mi barrio es MARIA AUXILIADORA
# yo soy de ASUNCION y mi barrio es LOS LAURELES
# yo soy de ITA y mi barrio es SAN ANTONIO

# %%
almuerzo_del_cliente = input('ingrese su pedido')
bebida_del_cliente = input('ingrese su bebida')
guarnicion_del_cliente = input('ingrese su guarnicion')


def pedido_del_cliente(almuerzo, bebida, guarnicion):
    print(f'preparando su pedido, {almuerzo}, {bebida}, {guarnicion} por favor, aguarde un momento')
    print('pedido listo, puede pasar a retirar')

pedido_del_cliente(almuerzo_del_cliente, bebida_del_cliente, guarnicion_del_cliente)
# Out:
# preparando su pedido, asado, coca cola, ensalada de papa por favor, aguarde un momento
# pedido listo, puede pasar a retirar

# %%
precio_del_producto = 20000
impuesto_global = 10

def calcular_total():
    precio_del_producto = 20000
    impuesto_global = 10
    print(precio_del_producto + impuesto_global)

calcular_total()
# Out:
# 20010
